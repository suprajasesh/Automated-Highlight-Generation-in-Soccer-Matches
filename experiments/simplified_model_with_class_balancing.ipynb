# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tqdm.notebook import tqdm
from google.colab import drive
import gc
from torch.nn.utils.rnn import pad_sequence

# Mount Google Drive
drive.mount('/content/drive')

# Path to your SoccerNet dataset shortcut
SOCCERNET_PATH = "/content/drive/MyDrive/soccernet"

# Define constants
FPS = 2  # ResNet features are extracted at 2 frames per second
WINDOW_SIZE = 20  # 10-second window (10s * 2fps = 20 frames)
STEP_SIZE = 5    # Step size for sliding window (2.5s)
EVENT_WINDOW = 2  # Number of frames around event to consider as event (+/-)

class EventMapper:
    """Maps event labels to numerical indices and vice versa"""

    def __init__(self):
        # List of event labels in SoccerNet-v2 - Focus on important events
        self.events = [
            "Shot", "Shot on target", "Goal", "Corner", "Yellow card", "Red card",
            "Penalty", "Kick-off", "Throw-in", "Foul"
        ]
        # Add "Background" class for frames without events
        self.events.append("Background")

        # Create mappings
        self.event_to_idx = {event: i for i, event in enumerate(self.events)}
        self.idx_to_event = {i: event for i, event in enumerate(self.events)}

    def get_num_classes(self):
        return len(self.events)

    def event_to_index(self, event):
        return self.event_to_idx.get(event, self.event_to_idx["Background"])

    def index_to_event(self, idx):
        return self.idx_to_event[idx]

def game_time_to_frame(game_time, fps=FPS):
    """Convert game time string (e.g. '1 - 00:00') to frame number"""
    half, time_str = game_time.split(" - ")
    minutes, seconds = time_str.split(":")

    # Convert to seconds
    total_seconds = int(half) * 45 * 60 + int(minutes) * 60 + int(seconds)

    # Convert to frame number
    frame_number = total_seconds * fps

    return frame_number

def load_labels(json_path):
    """Load labels from SoccerNet json file and convert to frame-level annotations"""
    with open(json_path, 'r') as f:
        data = json.load(f)

    annotations = data.get('annotations', [])
    frame_labels = []

    for annotation in annotations:
        game_time = annotation['gameTime']
        label = annotation['label']
        position = int(annotation['position'])  # Frame position in the video
        team = annotation['team']
        visibility = annotation['visibility']

        # Calculate the frame number from game time
        frame_number = game_time_to_frame(game_time)

        # Only include visible events and only events we're interested in
        if visibility == "visible":
            frame_labels.append({
                'frame': frame_number,
                'label': label,
                'position': position,
                'team': team
            })

    return frame_labels

def get_match_paths():
    """Return all match paths from the SoccerNet dataset"""
    match_paths = []

    # List of leagues
    leagues = ['england_epl', 'europe_uefa-champions-league', 'france_ligue-1',
               'germany_bundesliga', 'italy_serie-a', 'spain_laliga']

    # List of seasons
    seasons = ['2014-2015', '2015-2016', '2016-2017']

    # Traverse through all leagues and seasons
    for league in leagues:
        league_path = os.path.join(SOCCERNET_PATH, league)
        if not os.path.exists(league_path):
            print(f"Warning: League path {league_path} does not exist")
            continue

        for season in seasons:
            season_path = os.path.join(league_path, season)
            if not os.path.exists(season_path):
                print(f"Warning: Season path {season_path} does not exist")
                continue

            # Get all match directories
            for match_dir in os.listdir(season_path):
                match_path = os.path.join(season_path, match_dir)
                if os.path.isdir(match_path):
                    # Check if the required files exist
                    labels_path = os.path.join(match_path, 'Labels-v2.json')
                    half1_path = os.path.join(match_path, '1_ResNET_TF2.npy')
                    half2_path = os.path.join(match_path, '2_ResNET_TF2.npy')

                    if os.path.exists(labels_path) and os.path.exists(half1_path) and os.path.exists(half2_path):
                        match_paths.append(match_path)

    return match_paths

class SoccerNetDataset(Dataset):
    """Memory-efficient SoccerNet Dataset with balanced sampling"""

    def __init__(self, match_paths, event_mapper, max_matches=None, mode='train', feature_dim=2048):
        self.match_paths = match_paths[:max_matches] if max_matches else match_paths
        self.event_mapper = event_mapper
        self.mode = mode
        self.feature_dim = feature_dim
        self.samples = []
        self.event_samples = {i: [] for i in range(event_mapper.get_num_classes())}

        # Cache to store loaded features to avoid reloading
        self.feature_cache = {}

        # Pre-compute the indices (but don't load features yet)
        self._precompute_indices()

        # Balance dataset if in training mode
        if mode == 'train':
            self._balance_dataset()
        else:
            # For validation/test, limit background samples
            self._limit_background_samples()

    def _precompute_indices(self):
        """Precompute all sample indices without loading features"""
        for match_idx, match_path in enumerate(tqdm(self.match_paths, desc=f"Indexing {self.mode} matches")):
            try:
                # Load label data
                labels_path = os.path.join(match_path, 'Labels-v2.json')
                frame_labels = load_labels(labels_path)

                # We'll focus on specific event types (not all events) to improve model performance
                filtered_events = []
                for event in frame_labels:
                    if event['label'] in self.event_mapper.event_to_idx:
                        filtered_events.append(event)

                # Create a mapping from frame number to event label for each frame
                # A frame will be labeled as event if it's within EVENT_WINDOW of an actual event
                frame_to_label = {}
                for event in filtered_events:
                    frame = event['frame']
                    label = event['label']

                    # Label the event frame and surrounding frames
                    for offset in range(-EVENT_WINDOW, EVENT_WINDOW + 1):
                        target_frame = frame + offset
                        if target_frame >= 0:  # Ensure non-negative frame indices
                            frame_to_label[target_frame] = label

                # Process each half
                for half_idx in [1, 2]:
                    # Get the expected number of frames without loading features
                    half_file = os.path.join(match_path, f'{half_idx}_ResNET_TF2.npy')
                    if not os.path.exists(half_file):
                        continue

                    # Get array shape without loading whole array
                    with open(half_file, 'rb') as f:
                        version = np.lib.format.read_magic(f)
                        shape, _, _ = np.lib.format.read_array_header_1_0(f)
                        num_frames = shape[0]

                    # Create sliding window indices
                    for i in range(0, num_frames - WINDOW_SIZE + 1, STEP_SIZE):
                        middle_frame = i + WINDOW_SIZE // 2

                        # Adjust frame number to match global frame number
                        global_middle_frame = middle_frame
                        if half_idx == 2:
                            global_middle_frame += 45 * 60 * FPS  # Add 45 minutes worth of frames

                        # Determine the label
                        label = frame_to_label.get(global_middle_frame, "Background")
                        label_idx = self.event_mapper.event_to_index(label)

                        # Skip some unimportant events in our reduced event list
                        if label == "Background" and self.mode == 'train':
                            # In training mode, keep only some background samples
                            if np.random.random() > 0.05:  # Keep only 5% of background samples
                                continue

                        sample_info = (match_path, half_idx, i, middle_frame, label_idx)

                        # Add to samples list
                        self.samples.append(sample_info)

                        # Also add to event-specific list for balancing
                        self.event_samples[label_idx].append(sample_info)

            except Exception as e:
                print(f"Error processing {match_path}: {str(e)}")
                continue

    def _balance_dataset(self):
        """Balance the dataset by oversampling minority classes"""
        # Count samples per class
        class_counts = {i: len(samples) for i, samples in self.event_samples.items()}
        print(f"Original class distribution: {class_counts}")

        # Find the class with maximum samples (excluding background)
        background_idx = self.event_mapper.event_to_index("Background")
        event_counts = {cls: count for cls, count in class_counts.items() if cls != background_idx}

        if not event_counts:
            print("Warning: No event samples found!")
            return

        target_count = max(50, max(event_counts.values()))  # At least 50 samples per class

        # Limit background samples to avoid extreme imbalance
        background_limit = min(target_count * 2, len(self.event_samples[background_idx]))

        # Create balanced samples list
        balanced_samples = []

        # Add non-background samples with oversampling
        for cls, samples in self.event_samples.items():
            if len(samples) == 0:
                # Skip empty classes
                continue

            if cls == background_idx:
                # For background, limit the number
                if len(samples) > background_limit:
                    # Convert samples to array for choice function
                    sampled_indices = np.random.choice(len(samples), background_limit, replace=False)
                    balanced_samples.extend([samples[i] for i in sampled_indices])
                else:
                    balanced_samples.extend(samples)
            else:
                # For event classes, oversample to reach target_count
                sampled_indices = np.random.choice(len(samples), target_count, replace=len(samples) < target_count)
                balanced_samples.extend([samples[i] for i in sampled_indices])

        # Update samples list
        if len(balanced_samples) > 0:
            self.samples = balanced_samples

            # Recalculate class distribution
            new_distribution = {}
            for sample in self.samples:
                label = sample[4]
                if label not in new_distribution:
                    new_distribution[label] = 0
                new_distribution[label] += 1

            print(f"Balanced dataset: {len(self.samples)} samples")
            print(f"New class distribution: {new_distribution}")

    def _limit_background_samples(self):
        """Limit background samples in validation/test set"""
        background_idx = self.event_mapper.event_to_index("Background")
        background_samples = self.event_samples[background_idx]

        # Count total event samples
        total_event_samples = sum(len(samples) for cls, samples in self.event_samples.items()
                                if cls != background_idx)

        # Limit background samples to at most 5x the number of event samples
        background_limit = min(len(background_samples), total_event_samples * 5)

        if len(background_samples) > background_limit:
            # Sample a subset of background samples
            sampled_indices = np.random.choice(len(background_samples), background_limit, replace=False)
            sampled_background = [background_samples[i] for i in sampled_indices]

            # Create new samples list with all event samples and limited background
            new_samples = []
            for sample in self.samples:
                if sample[4] != background_idx:
                    new_samples.append(sample)

            new_samples.extend(sampled_background)
            self.samples = new_samples

            print(f"Limited {self.mode} background samples: {len(background_samples)} -> {background_limit}")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        match_path, half_idx, window_start, middle_frame, label = self.samples[idx]

        try:
            # Use cache key to avoid reloading the same files
            cache_key = (match_path, half_idx)

            if cache_key in self.feature_cache:
                features = self.feature_cache[cache_key]
            else:
                # Load features fully into memory (no memory mapping)
                half_file = os.path.join(match_path, f'{half_idx}_ResNET_TF2.npy')
                features = np.load(half_file)

                # Store in cache if we're not in training mode (to save memory)
                if self.mode != 'train':
                    self.feature_cache[cache_key] = features

            # Check valid range
            if window_start + WINDOW_SIZE > len(features):
                # Handle edge case where window extends beyond available frames
                available_frames = len(features) - window_start
                window_features = np.zeros((WINDOW_SIZE, self.feature_dim))
                window_features[:available_frames] = features[window_start:window_start+available_frames]
            else:
                # Get the window features
                window_features = features[window_start:window_start+WINDOW_SIZE]

            # Apply simple feature normalization
            window_features = (window_features - window_features.mean(axis=0)) / (window_features.std(axis=0) + 1e-5)

            return torch.tensor(window_features, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

        except Exception as e:
            print(f"Error loading sample {idx}: {str(e)}")
            # Return a dummy sample
            dummy_features = torch.zeros((WINDOW_SIZE, self.feature_dim), dtype=torch.float32)
            dummy_label = torch.tensor(self.event_mapper.event_to_index("Background"), dtype=torch.long)
            return dummy_features, dummy_label

    def cleanup_cache(self):
        """Clear feature cache to free memory"""
        self.feature_cache.clear()
        gc.collect()

class SimpleEventDetectionModel(nn.Module):
    """Simplified neural network for soccer event detection"""

    def __init__(self, input_dim, hidden_dim, num_classes, dropout_rate=0.5):
        super(SimpleEventDetectionModel, self).__init__()

        # Input dimension reduction
        self.feature_reducer = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout_rate)
        )

        # 1D convolutional layer for temporal pattern extraction
        self.conv1d = nn.Conv1d(hidden_dim, hidden_dim, kernel_size=3, padding=1)

        # LSTM layer
        self.lstm = nn.LSTM(
            input_size=hidden_dim,
            hidden_size=hidden_dim,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        # Attention mechanism
        self.attention = nn.Sequential(
            nn.Linear(hidden_dim * 2, 1),
            nn.Tanh()
        )

        # Output layer
        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, num_classes)
        )

        # Batch normalization for stability
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.bn2 = nn.BatchNorm1d(hidden_dim * 2)

    def forward(self, x):
        batch_size, seq_len, feat_dim = x.size()

        # Apply feature reduction
        x = x.view(-1, feat_dim)
        x = self.feature_reducer(x)
        x = x.view(batch_size, seq_len, -1)

        # Apply batch normalization
        x = x.permute(0, 2, 1)  # [batch, hidden_dim, seq_len]
        x = self.bn1(x)

        # 1D convolution for temporal patterns
        x = self.conv1d(x)
        x = x.permute(0, 2, 1)  # [batch, seq_len, hidden_dim]

        # LSTM processing
        lstm_out, _ = self.lstm(x)  # [batch, seq_len, hidden_dim*2]

        # Apply batch normalization
        lstm_out = lstm_out.permute(0, 2, 1)  # [batch, hidden_dim*2, seq_len]
        lstm_out = self.bn2(lstm_out)
        lstm_out = lstm_out.permute(0, 2, 1)  # [batch, seq_len, hidden_dim*2]

        # Apply attention
        attn_weights = self.attention(lstm_out).squeeze(-1)  # [batch, seq_len]
        attn_weights = torch.softmax(attn_weights, dim=1).unsqueeze(-1)  # [batch, seq_len, 1]

        # Context vector is weighted sum of LSTM outputs
        context = torch.sum(lstm_out * attn_weights, dim=1)  # [batch, hidden_dim*2]

        # Classification
        output = self.classifier(context)

        return output

def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10, device='cuda'):
    """Train the model with early stopping and learning rate scheduling"""
    # Move model to device
    model.to(device)

    # Training history
    train_losses = []
    val_losses = []
    val_accuracies = []

    # Early stopping variables
    best_val_loss = float('inf')
    best_model_state = None
    patience = 3
    patience_counter = 0

    # Learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, 'min', patience=1, factor=0.5, verbose=True
    )

    for epoch in range(num_epochs):
        # Training
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        background_idx = val_loader.dataset.event_mapper.event_to_index("Background")

        train_preds = []
        train_labels = []

        for batch_idx, (features, labels) in enumerate(tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} - Training")):
            features = features.to(device)
            labels = labels.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(features)
            loss = criterion(outputs, labels)

            # Backward pass and optimize
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

            running_loss += loss.item() * features.size(0)

            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            # Track predictions and labels for metrics
            train_preds.extend(predicted.cpu().numpy())
            train_labels.extend(labels.cpu().numpy())

            # Print batch statistics periodically
            if batch_idx % 20 == 0:
                batch_acc = (predicted == labels).sum().item() / labels.size(0)
                print(f"  Batch {batch_idx}: Loss={loss.item():.4f}, Acc={batch_acc:.4f}")

        epoch_train_loss = running_loss / len(train_loader.dataset)
        epoch_train_acc = correct / total
        train_losses.append(epoch_train_loss)

        # Print training metrics excluding background class
        non_bg_correct = 0
        non_bg_total = 0
        for i in range(len(train_labels)):
            if train_labels[i] != background_idx:
                non_bg_total += 1
                if train_labels[i] == train_preds[i]:
                    non_bg_correct += 1

        non_bg_acc = non_bg_correct / max(1, non_bg_total)
        print(f"Training - Event classes only: {non_bg_acc:.4f} ({non_bg_correct}/{non_bg_total})")

        # Validation
        val_metrics = evaluate_during_training(model, val_loader, criterion, device)
        epoch_val_loss = val_metrics['loss']
        epoch_val_acc = val_metrics['accuracy']
        epoch_val_event_acc = val_metrics['event_accuracy']

        val_losses.append(epoch_val_loss)
        val_accuracies.append(epoch_val_acc)

        print(f"Epoch {epoch+1}/{num_epochs} - "
              f"Train Loss: {epoch_train_loss:.4f}, Train Acc: {epoch_train_acc:.4f}, "
              f"Val Loss: {epoch_val_loss:.4f}, Val Acc: {epoch_val_acc:.4f}, "
              f"Val Event Acc: {epoch_val_event_acc:.4f}")

        # Print F1 scores for validation
        print(f"Validation F1 Scores: {val_metrics['f1_scores']}")

        # Check for early stopping
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            best_model_state = model.state_dict().copy()
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping triggered after {epoch+1} epochs")
                break

        # Update learning rate
        scheduler.step(epoch_val_loss)

        # Clean up memory
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    # Load the best model
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    # Additional metrics
    metrics = {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'val_accuracies': val_accuracies
    }

    return model, metrics

def evaluate_during_training(model, data_loader, criterion, device):
    """Evaluate model during training"""
    model.eval()
    total_loss = 0
    correct = 0
    total = 0

    all_preds = []
    all_labels = []

    background_idx = data_loader.dataset.event_mapper.event_to_index("Background")

    with torch.no_grad():
        for features, labels in data_loader:
            features = features.to(device)
            labels = labels.to(device)

            outputs = model(features)
            loss = criterion(outputs, labels)

            total_loss += loss.item() * features.size(0)

            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Calculate event-only accuracy (excluding background)
    non_bg_correct = 0
    non_bg_total = 0
    for i in range(len(all_labels)):
        if all_labels[i] != background_idx:
            non_bg_total += 1
            if all_labels[i] == all_preds[i]:
                non_bg_correct += 1

    # Calculate class-specific F1 scores
    from sklearn.metrics import f1_score

    # Convert to numpy arrays
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)

    # Calculate micro and macro F1 scores
    micro_f1 = f1_score(all_labels, all_preds, average='micro')
    macro_f1 = f1_score(all_labels, all_preds, average='macro')

    event_accuracy = non_bg_correct / max(1, non_bg_total)

    metrics = {
        'loss': total_loss / len(data_loader.dataset),
        'accuracy': correct / total,
        'event_accuracy': event_accuracy,
        'f1_scores': {
            'micro': micro_f1,
            'macro': macro_f1
        }
    }

    return metrics

def evaluate_model(model, test_loader, event_mapper, device='cuda'):
    """Evaluate the trained model"""
    model.eval()

    all_predictions = []
    all_labels = []
    background_idx = event_mapper.event_to_index("Background")

    with torch.no_grad():
        for features, labels in tqdm(test_loader, desc="Evaluating"):
            features = features.to(device)
            outputs = model(features)
            _, predictions = torch.max(outputs, 1)

            all_predictions.extend(predictions.cpu().numpy())
            all_labels.extend(labels.numpy())

    # Convert to numpy arrays
    all_predictions = np.array(all_predictions)
    all_labels = np.array(all_labels)

    # Extract non-background samples for separate evaluation
    event_mask = all_labels != background_idx
    event_predictions = all_predictions[event_mask]
    event_labels = all_labels[event_mask]

    # Find unique classes in the test data
    unique_classes = np.unique(np.concatenate([all_labels, all_predictions]))
    target_names = [event_mapper.index_to_event(i) for i in unique_classes]

    # Calculate metrics
    print("Overall Results:")
    overall_report = classification_report(
        all_labels,
        all_predictions,
        labels=unique_classes,
        target_names=target_names,
        zero_division=0
    )
    print(overall_report)

    if len(event_labels) > 0:
        print("\nEvent-Only Results (excluding background):")
        event_unique_classes = np.unique(np.concatenate([event_labels, event_predictions]))
        event_target_names = [event_mapper.index_to_event(i) for i in event_unique_classes]

        event_report = classification_report(
            event_labels,
            event_predictions,
            labels=event_unique_classes,
            target_names=event_target_names,
            zero_division=0
        )
        print(event_report)

    # Create confusion matrix
    plt.figure(figsize=(15, 15))
    cm = confusion_matrix(all_labels, all_predictions, labels=unique_classes)

    # Normalize confusion matrix
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cm_normalized = np.nan_to_num(cm_normalized)  # Replace NaN with 0

    sns.heatmap(
        cm_normalized,
        annot=True,
        fmt='.2f',
        cmap='Blues',
        xticklabels=target_names,
        yticklabels=target_names
    )
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Normalized Confusion Matrix')
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

    return overall_report, cm

def predict_events(model, match_path, event_mapper, device='cuda'):
    """Predict events for a given match"""
    model.eval()

    # Load ResNet features
    half1_features = np.load(os.path.join(match_path, '1_ResNET_TF2.npy'))
    half2_features = np.load(os.path.join(match_path, '2_ResNET_TF2.npy'))

    predictions = []
    background_idx = event_mapper.event_to_index("Background")

    for half_idx, features in enumerate([half1_features, half2_features], 1):
        num_frames = len(features)
        half_predictions = np.full(num_frames, background_idx)

        # Create sliding windows
        for i in range(0, num_frames - WINDOW_SIZE + 1, STEP_SIZE):
            window_features = features[i:i+WINDOW_SIZE]

            # Normalize features
            window_features = (window_features - window_features.mean(axis=0)) / (window_features.std(axis=0) + 1e-5)

            # Convert to tensor
            window_tensor = torch.tensor(window_features, dtype=torch.float32).unsqueeze(0).to(device)

            # Make prediction
            with torch.no_grad():
                outputs = model(window_tensor)
                _, predicted = torch.max(outputs, 1)
                predicted_class = predicted.item()

            # Only update if event is detected (not background)
            if predicted_class != background_idx:
                # Update prediction for the middle frame of the window
                middle_frame = i + WINDOW_SIZE // 2
                if middle_frame < num_frames:
                    half_predictions[middle_frame] = predicted_class

        # Add half predictions to the list
        predictions.append(half_predictions)

    # Convert predictions to event sequences
    events = []
    for half_idx, half_predictions in enumerate(predictions, 1):
        frame_idx = 0
        while frame_idx < len(half_predictions):
            class_idx = half_predictions[frame_idx]

            # Skip background frames
            if class_idx != background_idx:
                event_name = event_mapper.index_to_event(class_idx)

                # Calculate game time
                seconds = frame_idx / FPS
                minutes = int(seconds // 60)
                remaining_seconds = int(seconds % 60)

                # Add 45 minutes for second half
                if half_idx == 2:
                    minutes += 45

                game_time = f"{half_idx} - {minutes:02d}:{remaining_seconds:02d}"

                events.append({
                    'gameTime': game_time,
                    'label': event_name,
                    'half': half_idx,
                    'frame': frame_idx,
                    'confidence': 1.0  # We could add confidence scores here
                })

            frame_idx += 1

    return events, predictions

def main():
    # Check if GPU is available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")

    # Create event mapper
    event_mapper = EventMapper()
    print(f"Number of event classes: {event_mapper.get_num_classes()}")

    # Get all match paths
    match_paths = get_match_paths()
    print(f"Found {len(match_paths)} matches")

    # Split matches into train, validation, and test sets
    train_matches, temp_matches = train_test_split(match_paths, test_size=0.3, random_state=42)
    val_matches, test_matches = train_test_split(temp_matches, test_size=0.5, random_state=42)

    print(f"Training matches: {len(train_matches)}")
    print(f"Validation matches: {len(val_matches)}")
    print(f"Test matches: {len(test_matches)}")

    # Create datasets with balanced sampling
    print("Creating training dataset...")
    train_dataset = SoccerNetDataset(train_matches, event_mapper, max_matches=50, mode='train')

    print("Creating validation dataset...")
    val_dataset = SoccerNetDataset(val_matches, event_mapper, max_matches=10, mode='val')

    print("Creating test dataset...")
    test_dataset = SoccerNetDataset(test_matches, event_mapper, max_matches=10, mode='test')

    # Create data loaders with smaller batch sizes
    batch_size = 32  # Reduced from 64 to save memory
    num_workers = 2

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True  # Helps with GPU transfer
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )

    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )

    # Create model - use SimpleEventDetectionModel instead of EventDetectionModel
    input_dim = 2048  # ResNet features are 2048-dimensional
    hidden_dim = 256  # Single hidden dimension for SimpleEventDetectionModel
    num_classes = event_mapper.get_num_classes()

    model = SimpleEventDetectionModel(input_dim, hidden_dim, num_classes)
    print(model)

    # Define loss function with class weights to handle imbalance
    if hasattr(train_dataset, 'samples') and len(train_dataset.samples) > 0:
        # Calculate class weights based on inverse frequency
        labels = [sample[4] for sample in train_dataset.samples]
        class_counts = np.bincount(labels, minlength=num_classes)
        class_weights = 1.0 / np.clip(class_counts, 1, len(train_dataset))
        class_weights = class_weights / np.sum(class_weights) * num_classes
        class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)
        print("Class weights:", class_weights.cpu().numpy())
        criterion = nn.CrossEntropyLoss(weight=class_weights)
    else:
        criterion = nn.CrossEntropyLoss()

    # Use AdamW optimizer with weight decay
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)

    # Train model
    num_epochs = 10  # Increased from 3 to 5 for better convergence
    model, metrics = train_model(
        model,
        train_loader,
        val_loader,
        criterion,
        optimizer,
        num_epochs=num_epochs,
        device=device
    )

    # Clean up memory after training
    train_dataset.cleanup_cache()
    val_dataset.cleanup_cache()
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    # Plot training curves
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(metrics['train_losses'], label='Train Loss')
    plt.plot(metrics['val_losses'], label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(metrics['val_accuracies'], label='Val Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/soccernet_training_curves.png')
    plt.show()

    # Evaluate model
    report, cm = evaluate_model(model, test_loader, event_mapper, device=device)

    # Save model
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'train_losses': metrics['train_losses'],
        'val_losses': metrics['val_losses'],
        'val_accuracies': metrics['val_accuracies'],
    }, '/content/drive/MyDrive/soccernet_event_detection_model.pth')

    # Example: Predict events for a test match
    if len(test_matches) > 0:
        test_match = test_matches[0]
        print(f"Predicting events for match: {os.path.basename(test_match)}")

        events, predictions = predict_events(model, test_match, event_mapper, device=device)

        # Display predictions
        print(f"Predicted {len(events)} events:")
        for event in events[:10]:  # Display first 10 events
            print(f"{event['gameTime']}: {event['label']}")

        # Compare with ground truth
        labels_path = os.path.join(test_match, 'Labels-v2.json')
        if os.path.exists(labels_path):
            true_events = load_labels(labels_path)
            print(f"\nGround truth: {len(true_events)} events")
            for event in true_events[:10]:  # Display first 10 events
                print(f"{event['frame'] / FPS / 60:.2f} min: {event['label']}")

    # Clean up remaining memory
    test_dataset.cleanup_cache()
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    print("Done!")

if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Using device: cuda
# Number of event classes: 11
# Found 500 matches
# Training matches: 350
# Validation matches: 75
# Test matches: 75
# Creating training dataset...
# Indexing train matches:   0%|          | 0/50 [00:00<?, ?it/s]
# Original class distribution: {0: 0, 1: 0, 2: 75, 3: 198, 4: 61, 5: 2, 6: 3, 7: 27, 8: 685, 9: 570, 10: 5441}
# Balanced dataset: 6850 samples
# New class distribution: {2: 685, 3: 685, 4: 685, 5: 685, 6: 685, 7: 685, 8: 685, 9: 685, 10: 1370}
# Creating validation dataset...
# Indexing val matches:   0%|          | 0/10 [00:00<?, ?it/s]
# Limited val background samples: 21689 -> 1700
# Creating test dataset...
# Indexing test matches:   0%|          | 0/10 [00:00<?, ?it/s]
# Limited test background samples: 21490 -> 1795
# SimpleEventDetectionModel(
#   (feature_reducer): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (conv1d): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#   (lstm): LSTM(256, 256, batch_first=True, bidirectional=True)
#   (attention): Sequential(
#     (0): Linear(in_features=512, out_features=1, bias=True)
#     (1): Tanh()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=256, out_features=11, bias=True)
#   )
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# Class weights: [5.4660864e+00 5.4660864e+00 7.9796882e-03 7.9796882e-03 7.9796882e-03
#  7.9796882e-03 7.9796882e-03 7.9796882e-03 7.9796882e-03 7.9796882e-03
#  3.9898441e-03]
# Epoch 1/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=2.3794, Acc=0.1250
#   Batch 20: Loss=1.4455, Acc=0.3750
#   Batch 40: Loss=1.2507, Acc=0.4375
#   Batch 60: Loss=1.0936, Acc=0.5000
#   Batch 80: Loss=1.0993, Acc=0.5000
#   Batch 100: Loss=0.7375, Acc=0.6562
#   Batch 120: Loss=0.7429, Acc=0.5938
#   Batch 140: Loss=0.9286, Acc=0.6250
#   Batch 160: Loss=0.9568, Acc=0.5625
#   Batch 180: Loss=0.7570, Acc=0.5312
#   Batch 200: Loss=0.9167, Acc=0.6250
# Training - Event classes only: 0.6339 (3474/5480)
# Epoch 1/10 - Train Loss: 1.0571, Train Acc: 0.5431, Val Loss: 1.8103, Val Acc: 0.0569, Val Event Acc: 0.2235
# Validation F1 Scores: {'micro': 0.056862745098039215, 'macro': 0.0339996120038858}
# Epoch 2/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=0.7936, Acc=0.6562
#   Batch 20: Loss=0.8061, Acc=0.5625
#   Batch 40: Loss=0.8416, Acc=0.5625
#   Batch 60: Loss=0.6179, Acc=0.7188
#   Batch 80: Loss=0.5065, Acc=0.7188
#   Batch 100: Loss=0.6592, Acc=0.7500
#   Batch 120: Loss=0.6309, Acc=0.6562
#   Batch 140: Loss=0.7042, Acc=0.6875
#   Batch 160: Loss=0.7881, Acc=0.6250
#   Batch 180: Loss=0.3155, Acc=0.7812
#   Batch 200: Loss=0.7331, Acc=0.5938
# Training - Event classes only: 0.7816 (4283/5480)
# Epoch 2/10 - Train Loss: 0.6446, Train Acc: 0.6728, Val Loss: 1.5856, Val Acc: 0.1206, Val Event Acc: 0.3176
# Validation F1 Scores: {'micro': 0.12058823529411765, 'macro': 0.04330988238086592}
# Epoch 3/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=0.5739, Acc=0.6875
#   Batch 20: Loss=0.5033, Acc=0.7812
#   Batch 40: Loss=0.4940, Acc=0.7188
#   Batch 60: Loss=0.4069, Acc=0.7500
#   Batch 80: Loss=0.3974, Acc=0.7500
#   Batch 100: Loss=0.5888, Acc=0.6562
#   Batch 120: Loss=0.6984, Acc=0.7188
#   Batch 140: Loss=0.6980, Acc=0.5938
#   Batch 160: Loss=0.4166, Acc=0.7812
#   Batch 180: Loss=0.4784, Acc=0.7188
#   Batch 200: Loss=0.5335, Acc=0.7188
# Training - Event classes only: 0.8224 (4507/5480)
# Epoch 3/10 - Train Loss: 0.5363, Train Acc: 0.7201, Val Loss: 1.5666, Val Acc: 0.0922, Val Event Acc: 0.3853
# Validation F1 Scores: {'micro': 0.09215686274509804, 'macro': 0.040218684025535675}
# Epoch 4/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=0.5191, Acc=0.6562
#   Batch 20: Loss=0.4926, Acc=0.7500
#   Batch 40: Loss=0.2766, Acc=0.7812
#   Batch 60: Loss=0.5184, Acc=0.6875
#   Batch 80: Loss=0.6867, Acc=0.6562
#   Batch 100: Loss=0.3172, Acc=0.8125
#   Batch 120: Loss=0.2401, Acc=0.8438
#   Batch 140: Loss=0.2222, Acc=0.9062
#   Batch 160: Loss=0.4509, Acc=0.7188
#   Batch 180: Loss=0.6349, Acc=0.6562
#   Batch 200: Loss=0.3740, Acc=0.8438
# Training - Event classes only: 0.8498 (4657/5480)
# Epoch 4/10 - Train Loss: 0.4467, Train Acc: 0.7581, Val Loss: 1.4122, Val Acc: 0.3250, Val Event Acc: 0.2176
# Validation F1 Scores: {'micro': 0.325, 'macro': 0.07604063529868281}
# Epoch 5/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=0.3763, Acc=0.8438
#   Batch 20: Loss=0.1827, Acc=0.9062
#   Batch 40: Loss=0.3632, Acc=0.8125
#   Batch 60: Loss=0.1165, Acc=0.9688
#   Batch 80: Loss=0.5398, Acc=0.7812
#   Batch 100: Loss=0.2630, Acc=0.8125
#   Batch 120: Loss=0.2443, Acc=0.8750
#   Batch 140: Loss=0.5405, Acc=0.7188
#   Batch 160: Loss=0.3012, Acc=0.8125
#   Batch 180: Loss=0.6922, Acc=0.6875
#   Batch 200: Loss=0.3969, Acc=0.7500
# Training - Event classes only: 0.8765 (4803/5480)
# Epoch 5/10 - Train Loss: 0.4021, Train Acc: 0.7785, Val Loss: 1.3786, Val Acc: 0.4436, Val Event Acc: 0.1618
# Validation F1 Scores: {'micro': 0.44362745098039214, 'macro': 0.09046960556586064}
# Epoch 6/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=0.4130, Acc=0.7500
#   Batch 20: Loss=0.4075, Acc=0.7500
#   Batch 40: Loss=0.3750, Acc=0.8125
#   Batch 60: Loss=0.2813, Acc=0.8125
#   Batch 80: Loss=0.6004, Acc=0.6562
#   Batch 100: Loss=0.2904, Acc=0.6875
#   Batch 120: Loss=0.4116, Acc=0.6875
#   Batch 140: Loss=0.4893, Acc=0.6875
#   Batch 160: Loss=0.3195, Acc=0.7812
#   Batch 180: Loss=0.2248, Acc=0.8750
#   Batch 200: Loss=0.3058, Acc=0.7812
# Training - Event classes only: 0.8951 (4905/5480)
# Epoch 6/10 - Train Loss: 0.3570, Train Acc: 0.7931, Val Loss: 1.3519, Val Acc: 0.3304, Val Event Acc: 0.2059
# Validation F1 Scores: {'micro': 0.3303921568627451, 'macro': 0.08033682466631288}
# Epoch 7/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=0.3897, Acc=0.7812
#   Batch 20: Loss=0.2034, Acc=0.9062
#   Batch 40: Loss=0.3077, Acc=0.8125
#   Batch 60: Loss=0.2836, Acc=0.8438
#   Batch 80: Loss=0.1714, Acc=0.8438
#   Batch 100: Loss=0.3057, Acc=0.8125
#   Batch 120: Loss=0.4096, Acc=0.7188
#   Batch 140: Loss=0.2618, Acc=0.8438
#   Batch 160: Loss=0.3545, Acc=0.8438
#   Batch 180: Loss=0.1860, Acc=0.9375
#   Batch 200: Loss=0.5130, Acc=0.8125
# Training - Event classes only: 0.9100 (4987/5480)
# Epoch 7/10 - Train Loss: 0.3240, Train Acc: 0.8114, Val Loss: 1.2540, Val Acc: 0.6711, Val Event Acc: 0.0647
# Validation F1 Scores: {'micro': 0.671078431372549, 'macro': 0.11687931650975908}
# Epoch 8/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=0.2862, Acc=0.8438
#   Batch 20: Loss=0.3613, Acc=0.8125
#   Batch 40: Loss=0.2609, Acc=0.8750
#   Batch 60: Loss=0.3483, Acc=0.7812
#   Batch 80: Loss=0.1182, Acc=0.8750
#   Batch 100: Loss=0.2453, Acc=0.8125
#   Batch 120: Loss=0.3512, Acc=0.8750
#   Batch 140: Loss=0.4218, Acc=0.7500
#   Batch 160: Loss=0.4172, Acc=0.8750
#   Batch 180: Loss=0.2831, Acc=0.7812
#   Batch 200: Loss=0.2001, Acc=0.8750
# Training - Event classes only: 0.9106 (4990/5480)
# Epoch 8/10 - Train Loss: 0.2992, Train Acc: 0.8273, Val Loss: 1.5227, Val Acc: 0.3397, Val Event Acc: 0.2441
# Validation F1 Scores: {'micro': 0.3397058823529412, 'macro': 0.08246146393506483}
# Epoch 9/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=0.2270, Acc=0.8438
#   Batch 20: Loss=0.2781, Acc=0.8438
#   Batch 40: Loss=0.2849, Acc=0.8438
#   Batch 60: Loss=0.1710, Acc=0.9062
#   Batch 80: Loss=0.1449, Acc=0.8750
#   Batch 100: Loss=0.2413, Acc=0.8125
#   Batch 120: Loss=0.4047, Acc=0.8125
#   Batch 140: Loss=0.3723, Acc=0.7500
#   Batch 160: Loss=0.2922, Acc=0.8125
#   Batch 180: Loss=0.3302, Acc=0.8438
#   Batch 200: Loss=0.4277, Acc=0.8750
# Training - Event classes only: 0.9226 (5056/5480)
# Epoch 9/10 - Train Loss: 0.2738, Train Acc: 0.8454, Val Loss: 1.3963, Val Acc: 0.4627, Val Event Acc: 0.1441
# Validation F1 Scores: {'micro': 0.4627450980392157, 'macro': 0.10191020852074681}
# Epoch 10/10 - Training:   0%|          | 0/215 [00:00<?, ?it/s]
#   Batch 0: Loss=0.1587, Acc=0.9688
#   Batch 20: Loss=0.1309, Acc=0.8750
#   Batch 40: Loss=0.3186, Acc=0.8125
#   Batch 60: Loss=0.1670, Acc=0.8750
#   Batch 80: Loss=0.3968, Acc=0.8750
#   Batch 100: Loss=0.1879, Acc=0.9062
#   Batch 120: Loss=0.1797, Acc=0.8750
#   Batch 140: Loss=0.1886, Acc=0.8438
#   Batch 160: Loss=0.1730, Acc=0.9375
#   Batch 180: Loss=0.2037, Acc=0.8750
#   Batch 200: Loss=0.1257, Acc=0.9062
# Training - Event classes only: 0.9443 (5175/5480)
# Epoch 10/10 - Train Loss: 0.2204, Train Acc: 0.8750, Val Loss: 1.3423, Val Acc: 0.5510, Val Event Acc: 0.1353
# Validation F1 Scores: {'micro': 0.5509803921568628, 'macro': 0.11524124165071456}
# Early stopping triggered after 10 epochs
# Evaluating:   0%|          | 0/68 [00:00<?, ?it/s]
# Overall Results:
#               precision    recall  f1-score   support
#
#         Goal       0.00      0.00      0.00        13
#       Corner       0.03      0.04      0.03        51
#  Yellow card       0.00      0.00      0.00        10
#     Red card       0.00      0.00      0.00         3
#      Penalty       0.00      0.00      0.00         2
#     Kick-off       0.00      0.00      0.00         3
#     Throw-in       0.07      0.26      0.11       155
#         Foul       0.01      0.01      0.01       122
#   Background       0.83      0.65      0.73      1795
#
#     accuracy                           0.56      2154
#    macro avg       0.10      0.11      0.10      2154
# weighted avg       0.70      0.56      0.62      2154
#
#
# Event-Only Results (excluding background):
#               precision    recall  f1-score   support
#
#         Goal       0.00      0.00      0.00        13
#       Corner       0.20      0.04      0.07        51
#  Yellow card       0.00      0.00      0.00        10
#     Red card       0.00      0.00      0.00         3
#      Penalty       0.00      0.00      0.00         2
#     Kick-off       0.00      0.00      0.00         3
#     Throw-in       0.40      0.26      0.32       155
#         Foul       0.10      0.01      0.02       122
#   Background       0.00      0.00      0.00         0
#
#     accuracy                           0.12       359
#    macro avg       0.08      0.03      0.04       359
# weighted avg       0.23      0.12      0.15       359
# Predicting events for match: 2015-04-29 - 21-45 Juventus 3 - 2 Fiorentina
# Predicted 707 events:
# 1 - 00:25: Throw-in
# 1 - 00:27: Throw-in
# 1 - 00:30: Throw-in
# 1 - 00:32: Throw-in
# 1 - 00:35: Throw-in
# 1 - 00:37: Throw-in
# 1 - 00:40: Foul
# 1 - 01:05: Throw-in
# 1 - 01:07: Throw-in
# 1 - 01:10: Throw-in
#
# Ground truth: 176 events
# 45.78 min: Ball out of play
# 46.05 min: Throw-in
# 46.70 min: Ball out of play
# 46.97 min: Throw-in
# 47.87 min: Foul
# 48.55 min: Indirect free-kick
# 48.82 min: Ball out of play
# 49.37 min: Corner
# 50.27 min: Ball out of play
# 50.68 min: Corner
# Done!
