# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
import numpy as np
import os
import json
import wandb
import glob
import librosa
from moviepy.editor import VideoFileClip
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':

# %%
import wandb
# Initialize WandB
wandb.login(key='add api key')
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: supraja2010341 (fyproject) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# Model Definition
class TemporalEncoder(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super().__init__()
        self.conv = nn.Conv1d(input_dim, hidden_dim, kernel_size=3, padding=1)
        self.lstm = nn.LSTM(hidden_dim, hidden_dim // 2, bidirectional=True, batch_first=True)
        self.norm = nn.LayerNorm(hidden_dim)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # (batch, time, dim) -> (batch, dim, time)
        x = self.conv(x).relu()
        x = x.permute(0, 2, 1)  # (batch, time, hidden_dim)
        x, _ = self.lstm(x)
        x = self.norm(x)
        return x

# %%
class HighlightModel(nn.Module):
    def __init__(self, video_dim, audio_dim, hidden_dim):
        super().__init__()
        self.video_encoder = TemporalEncoder(video_dim, hidden_dim)
        self.audio_encoder = TemporalEncoder(audio_dim, hidden_dim)
        self.fusion = nn.Linear(hidden_dim * 2, hidden_dim)
        self.scorer = nn.Linear(hidden_dim, 1)

    def forward(self, video, audio, event_timestamps):
        event_timestamps=event_timestamps.long()
        video_features = self.video_encoder(video)  # (batch, time, hidden)
        audio_features = self.audio_encoder(audio)  # (batch, time, hidden)
        fused_features = torch.cat([video_features, audio_features], dim=-1)  # (batch, time, hidden*2)
        fused_features = self.fusion(fused_features).relu()  # (batch, time, hidden)
        event_features = fused_features[torch.arange(fused_features.size(0))[:, None], event_timestamps]
        scores = self.scorer(event_features).sigmoid()  # (batch, num_events, 1)
        return scores.squeeze(-1)  # (batch, num_events)

# %%
class SoccerNetDataset:
    def __init__(self, data_dir, split_file, feature_rate=1, max_events=50, device="cuda", top=10):
        self.data_dir = data_dir
        self.feature_rate = feature_rate
        self.max_events = max_events
        self.device = device
        self.game_dirs = self._load_games(split_file)[:top]

    def _load_games(self, split_file):
        with open(split_file) as f:
            game_dirs = json.load(f)
        valid_dirs = [d for d in game_dirs if os.path.exists(d)]
        if len(valid_dirs) < len(game_dirs):
            print(f"Warning: {len(game_dirs) - len(valid_dirs)} game directories not found")
        return valid_dirs

    def _load_video_features(self, game_dir):
        feature_files = sorted(glob.glob(os.path.join(game_dir, "*_ResNET_TF2.npy")))
        if len(feature_files) < 2:
            raise FileNotFoundError(f"Expected 1_ResNET_TF2.npy and 2_ResNET_TF2.npy in {game_dir}, found {len(feature_files)}")
        features1 = np.load(feature_files[0])
        features2 = np.load(feature_files[1])
        video_features = np.concatenate([features1, features2], axis=0)
        return torch.tensor(video_features, dtype=torch.float32).to(self.device)

    def _load_audio_features(self, game_dir, target_length):
        audio_files = sorted(glob.glob(os.path.join(game_dir, "*_224p.wav")))
        if len(audio_files) < 2:
            raise FileNotFoundError(f"Expected 1_224p.wav and 2_224p.wav in {game_dir}, found {len(audio_files)}")
        mfccs = []
        audio_signals = []
        sr = None
        for audio_file in audio_files:
            y, sr = librosa.load(audio_file, sr=None)
            hop_length = int(sr / self.feature_rate)
            mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20, hop_length=hop_length)
            mfccs.append(mfcc.T)
            audio_signals.append(y)
        audio_features = np.concatenate(mfccs, axis=0)
        audio_features = librosa.util.fix_length(audio_features.T, size=target_length, axis=1).T
        audio_signal = np.concatenate(audio_signals)
        return (torch.tensor(audio_features, dtype=torch.float32).to(self.device),
                audio_signal, sr)

    def _parse_game_time(self, game_time):
        half, time_str = game_time.split(" - ")
        minutes, seconds = map(int, time_str.split(":"))
        total_seconds = minutes * 60 + seconds
        return int(half), total_seconds

    def _load_event_timestamps(self, game_dir, video_length, audio_signal, sr):
        annotation_file = os.path.join(game_dir, "Labels-v2.json")
        if not os.path.exists(annotation_file):
            raise FileNotFoundError(f"No Labels-v2.json found in {game_dir}")
        with open(annotation_file) as f:
            data = json.load(f)
        events = data.get("annotations", [])
        half1_duration = self._get_half1_duration(os.path.join(game_dir, "1_224p.mp4"))
        half1_duration_frames = int(half1_duration * self.feature_rate)

        timestamps = []
        audio_scores = []
        event_names = []
        window_seconds = 5
        window_samples = int(window_seconds * sr)

        for event in events:
            half, time_seconds = self._parse_game_time(event["gameTime"])
            timestamp = int(time_seconds * self.feature_rate)
            if half == 2:
                timestamp += half1_duration_frames
            if timestamp < video_length:
                timestamps.append(timestamp)
                event_names.append(event.get("label", "Unknown"))
                audio_time = time_seconds + (half1_duration if half == 2 else 0)
                center_sample = int(audio_time * sr)
                start_sample = max(0, center_sample - window_samples)
                end_sample = min(len(audio_signal), center_sample + window_samples)
                window = audio_signal[start_sample:end_sample]
                rms = librosa.feature.rms(y=window, frame_length=2048, hop_length=512)
                score = np.mean(rms) if rms.size > 0 else 0.0
                audio_scores.append(score)

        if audio_scores:
            audio_scores = np.array(audio_scores)
            min_score, max_score = audio_scores.min(), audio_scores.max()
            if max_score > min_score:
                audio_scores = (audio_scores - min_score) / (max_score - min_score)
            else:
                audio_scores = np.zeros_like(audio_scores)

        num_events = len(timestamps)
        if num_events == 0:
            timestamps = [0]
            audio_scores = [0.0]
            event_names = ["None"]
            num_events = 0
        if num_events > self.max_events:
            timestamps = timestamps[:self.max_events]
            audio_scores = audio_scores[:self.max_events]
            event_names = event_names[:self.max_events]
            num_events = self.max_events
        else:
            timestamps += [0] * (self.max_events - num_events)
            audio_scores += [0.0] * (self.max_events - num_events)
            event_names += ["Padding"] * (self.max_events - num_events)

        return (torch.tensor(timestamps, dtype=torch.long),
                torch.tensor(audio_scores, dtype=torch.float32),
                num_events,
                event_names)

    def _get_half1_duration(self, video_path):
        try:
            video = VideoFileClip(video_path)
            duration = video.duration
            video.close()
            return duration
        except Exception:
            return 2700

    def __len__(self):
        return len(self.game_dirs)

    def __getitem__(self, idx):
        game_dir = self.game_dirs[idx]
        try:
            video_tensor = self._load_video_features(game_dir)
            audio_tensor, audio_signal, sr = self._load_audio_features(game_dir, video_tensor.shape[0])
            timestamps, scores, num_events, event_names = self._load_event_timestamps(game_dir, video_tensor.shape[0], audio_signal, sr)
            return {
                "video": video_tensor,
                "audio": audio_tensor,
                "timestamps": timestamps.to(self.device),
                "scores": scores.to(self.device),
                "num_events": num_events,
                "event_names": event_names
            }
        except Exception as e:
            print(f"Skipping {game_dir} due to error: {e}")
            return None

# %%
def custom_collate(batch):
    batch = [b for b in batch if b is not None]
    if not batch:
        return None

    videos = [b["video"].clone().detach() for b in batch]
    audios = [b["audio"].clone().detach() for b in batch]
    timestamps = [b["timestamps"].clone().detach().long() for b in batch]
    scores = [b["scores"].clone().detach() for b in batch]
    num_events = [b["num_events"] for b in batch]
    event_names = [b["event_names"] for b in batch]

    padded_videos = pad_sequence(videos, batch_first=True)
    padded_audios = pad_sequence(audios, batch_first=True)
    padded_timestamps = pad_sequence(timestamps, batch_first=True)
    padded_scores = pad_sequence(scores, batch_first=True)

    return {
        "video": padded_videos,
        "audio": padded_audios,
        "timestamps": padded_timestamps,
        "scores": padded_scores,
        "num_events": num_events,
        "event_names": event_names
    }

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from collections import defaultdict
import wandb

def test_model(data_dir, test_split, batch_size=4, device="cuda"):
    wandb.init(project="soccernet_highlights-test", config={
        "batch_size": batch_size,
        "video_dim": 2048,
        "audio_dim": 20,
        "hidden_dim": 512,
        "phase": "test"
    })

    test_dataset = SoccerNetDataset(data_dir, test_split, device=device, top=10)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0, collate_fn=custom_collate)

    print(f"Test dataset size: {len(test_dataset)} games")

    model = HighlightModel(video_dim=2048, audio_dim=20, hidden_dim=512).to(device)
    model.load_state_dict(torch.load("highlight_model.pth"))
    model.eval()

    criterion = nn.BCELoss()

    test_loss = 0.0
    test_mae = 0.0
    test_count = 0
    test_batches = 0
    test_correct = 0
    test_total = 0

    # Dictionary to store event names and scores grouped by match index
    match_events_scores = defaultdict(list)

    with torch.no_grad():
        for batch_idx, batch in enumerate(test_loader):
            if batch is None:
                continue

            video = batch["video"].to(device)
            audio = batch["audio"].to(device)
            timestamps = batch["timestamps"].to(device)
            scores = batch["scores"].to(device)
            num_events = batch["num_events"]
            event_names = batch["event_names"]

            pred_scores = model(video, audio, timestamps)

            loss = torch.tensor(0.0, device=device)
            for i in range(len(num_events)):
                if num_events[i] > 0:
                    valid_scores = pred_scores[i, :num_events[i]]
                    valid_gt = scores[i, :num_events[i]]
                    valid_names = event_names[i][:num_events[i]]
                    loss = loss + criterion(valid_scores, valid_gt)

                    test_mae += torch.mean(torch.abs(valid_scores - valid_gt)).item()
                    test_count += 1

                    pred_labels = (valid_scores >= 0.5).float()
                    test_correct += (pred_labels == valid_gt).float().sum().item()
                    test_total += valid_gt.numel()

                    # Store match-wise event names and predicted scores
                    for name, score in zip(valid_names, valid_scores.cpu().numpy()):
                        match_events_scores[batch_idx * batch_size + i].append((name, score))

            if test_count > 0:
                batch_loss = (loss / len(num_events)).item()
                test_loss += batch_loss
                test_batches += 1

                print(f"Test Batch {batch_idx + 1}/{len(test_loader)}, "
                      f"Test Loss: {batch_loss:.4f}, Test MAE: {test_mae / test_count:.4f}")

    # Print all events and their scores match-wise in decreasing order
    print("\nAll events and their predicted scores (sorted match-wise in decreasing order):")
    for match_id in sorted(match_events_scores.keys()):
        print(f"\nMatch {match_id + 1}:")
        events = sorted(match_events_scores[match_id], key=lambda x: x[1], reverse=True)
        for event, score in events:
            print(f"Event: {event}, Predicted Score: {score:.4f}")

    # Calculate final metrics
    test_loss = test_loss / test_batches if test_batches > 0 else 0.0
    test_mae = test_mae / test_count if test_count > 0 else 0.0
    test_accuracy = test_correct / test_total if test_total > 0 else 0.0

    wandb.log({
        "test_loss": test_loss,
        "test_mae": test_mae,
        "test_accuracy": test_accuracy
    })

    print(f"\nTest Results: Loss: {test_loss:.4f}, MAE: {test_mae:.4f}, Accuracy: {test_accuracy:.4f}")

    wandb.finish()

# %%
if __name__ == "__main__":
    data_dir = "/content/drive/MyDrive/soccernet"
    test_split = os.path.join(data_dir, "test.json")
    test_model(data_dir, test_split, batch_size=4, device="cuda")
# Out:
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250506_060615-uvvhr68l</code>
# Syncing run <strong><a href='https://wandb.ai/fyproject/soccernet_highlights-test/runs/uvvhr68l' target="_blank">decent-sun-12</a></strong> to <a href='https://wandb.ai/fyproject/soccernet_highlights-test' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/fyproject/soccernet_highlights-test' target="_blank">https://wandb.ai/fyproject/soccernet_highlights-test</a>
#  View run at <a href='https://wandb.ai/fyproject/soccernet_highlights-test/runs/uvvhr68l' target="_blank">https://wandb.ai/fyproject/soccernet_highlights-test/runs/uvvhr68l</a>
# Test dataset size: 10 games
# Test Batch 1/3, Test Loss: 0.6673, Test MAE: 0.1472
# Test Batch 2/3, Test Loss: 0.6937, Test MAE: 0.1594
# Test Batch 3/3, Test Loss: 0.6939, Test MAE: 0.1525
#
# All events and their predicted scores (sorted match-wise in decreasing order):
#
# Match 1:
# Event: Kick-off, Predicted Score: 0.4977
# Event: Ball out of play, Predicted Score: 0.4401
# Event: Ball out of play, Predicted Score: 0.4400
# Event: Offside, Predicted Score: 0.4398
# Event: Ball out of play, Predicted Score: 0.4391
# Event: Throw-in, Predicted Score: 0.4364
# Event: Indirect free-kick, Predicted Score: 0.4355
# Event: Ball out of play, Predicted Score: 0.4344
# Event: Shots on target, Predicted Score: 0.4340
# Event: Clearance, Predicted Score: 0.4332
# Event: Foul, Predicted Score: 0.4331
# Event: Foul, Predicted Score: 0.4329
# Event: Ball out of play, Predicted Score: 0.4326
# Event: Clearance, Predicted Score: 0.4321
# Event: Ball out of play, Predicted Score: 0.4320
# Event: Ball out of play, Predicted Score: 0.4316
# Event: Foul, Predicted Score: 0.4308
# Event: Shots on target, Predicted Score: 0.4301
# Event: Shots off target, Predicted Score: 0.4289
# Event: Ball out of play, Predicted Score: 0.4288
# Event: Ball out of play, Predicted Score: 0.4282
# Event: Foul, Predicted Score: 0.4276
# Event: Clearance, Predicted Score: 0.4275
# Event: Throw-in, Predicted Score: 0.4273
# Event: Ball out of play, Predicted Score: 0.4260
# Event: Direct free-kick, Predicted Score: 0.4259
# Event: Throw-in, Predicted Score: 0.4254
# Event: Shots on target, Predicted Score: 0.4254
# Event: Indirect free-kick, Predicted Score: 0.4253
# Event: Direct free-kick, Predicted Score: 0.4252
# Event: Ball out of play, Predicted Score: 0.4252
# Event: Ball out of play, Predicted Score: 0.4252
# Event: Throw-in, Predicted Score: 0.4251
# Event: Ball out of play, Predicted Score: 0.4251
# Event: Throw-in, Predicted Score: 0.4251
# Event: Clearance, Predicted Score: 0.4251
# Event: Corner, Predicted Score: 0.4251
# Event: Shots off target, Predicted Score: 0.4251
# Event: Corner, Predicted Score: 0.4251
# Event: Ball out of play, Predicted Score: 0.4251
# Event: Foul, Predicted Score: 0.4251
# Event: Throw-in, Predicted Score: 0.4251
# Event: Clearance, Predicted Score: 0.4251
# Event: Throw-in, Predicted Score: 0.4251
# Event: Indirect free-kick, Predicted Score: 0.4251
# Event: Throw-in, Predicted Score: 0.4251
# Event: Ball out of play, Predicted Score: 0.4251
# Event: Foul, Predicted Score: 0.4250
# Event: Clearance, Predicted Score: 0.4250
# Event: Indirect free-kick, Predicted Score: 0.4249
#
# Match 2:
# Event: Kick-off, Predicted Score: 0.5047
# Event: Shots on target, Predicted Score: 0.4456
# Event: Goal, Predicted Score: 0.4450
# Event: Yellow card, Predicted Score: 0.4428
# Event: Ball out of play, Predicted Score: 0.4427
# Event: Ball out of play, Predicted Score: 0.4411
# Event: Ball out of play, Predicted Score: 0.4410
# Event: Kick-off, Predicted Score: 0.4409
# Event: Throw-in, Predicted Score: 0.4408
# Event: Ball out of play, Predicted Score: 0.4407
# Event: Corner, Predicted Score: 0.4407
# Event: Indirect free-kick, Predicted Score: 0.4405
# Event: Foul, Predicted Score: 0.4405
# Event: Foul, Predicted Score: 0.4405
# Event: Clearance, Predicted Score: 0.4404
# Event: Foul, Predicted Score: 0.4402
# Event: Ball out of play, Predicted Score: 0.4392
# Event: Shots on target, Predicted Score: 0.4391
# Event: Ball out of play, Predicted Score: 0.4385
# Event: Shots on target, Predicted Score: 0.4384
# Event: Ball out of play, Predicted Score: 0.4375
# Event: Shots off target, Predicted Score: 0.4372
# Event: Foul, Predicted Score: 0.4368
# Event: Ball out of play, Predicted Score: 0.4362
# Event: Ball out of play, Predicted Score: 0.4357
# Event: Clearance, Predicted Score: 0.4348
# Event: Ball out of play, Predicted Score: 0.4334
# Event: Throw-in, Predicted Score: 0.4333
# Event: Ball out of play, Predicted Score: 0.4331
# Event: Clearance, Predicted Score: 0.4325
# Event: Indirect free-kick, Predicted Score: 0.4321
# Event: Ball out of play, Predicted Score: 0.4308
# Event: Indirect free-kick, Predicted Score: 0.4305
# Event: Throw-in, Predicted Score: 0.4290
# Event: Throw-in, Predicted Score: 0.4286
# Event: Ball out of play, Predicted Score: 0.4280
# Event: Indirect free-kick, Predicted Score: 0.4270
# Event: Throw-in, Predicted Score: 0.4267
# Event: Clearance, Predicted Score: 0.4256
# Event: Corner, Predicted Score: 0.4255
# Event: Throw-in, Predicted Score: 0.4255
# Event: Foul, Predicted Score: 0.4255
# Event: Foul, Predicted Score: 0.4254
# Event: Indirect free-kick, Predicted Score: 0.4254
# Event: Indirect free-kick, Predicted Score: 0.4253
# Event: Throw-in, Predicted Score: 0.4252
# Event: Ball out of play, Predicted Score: 0.4251
# Event: Clearance, Predicted Score: 0.4251
# Event: Ball out of play, Predicted Score: 0.4251
# Event: Throw-in, Predicted Score: 0.4251
#
# Match 3:
# Event: Kick-off, Predicted Score: 0.5014
# Event: Foul, Predicted Score: 0.4455
# Event: Shots off target, Predicted Score: 0.4449
# Event: Indirect free-kick, Predicted Score: 0.4418
# Event: Ball out of play, Predicted Score: 0.4411
# Event: Ball out of play, Predicted Score: 0.4411
# Event: Clearance, Predicted Score: 0.4409
# Event: Ball out of play, Predicted Score: 0.4406
# Event: Indirect free-kick, Predicted Score: 0.4405
# Event: Shots on target, Predicted Score: 0.4405
# Event: Throw-in, Predicted Score: 0.4405
# Event: Ball out of play, Predicted Score: 0.4405
# Event: Shots on target, Predicted Score: 0.4405
# Event: Foul, Predicted Score: 0.4402
# Event: Throw-in, Predicted Score: 0.4392
# Event: Ball out of play, Predicted Score: 0.4392
# Event: Ball out of play, Predicted Score: 0.4391
# Event: Ball out of play, Predicted Score: 0.4388
# Event: Foul, Predicted Score: 0.4376
# Event: Ball out of play, Predicted Score: 0.4366
# Event: Clearance, Predicted Score: 0.4358
# Event: Throw-in, Predicted Score: 0.4349
# Event: Indirect free-kick, Predicted Score: 0.4345
# Event: Clearance, Predicted Score: 0.4332
# Event: Throw-in, Predicted Score: 0.4328
# Event: Ball out of play, Predicted Score: 0.4327
# Event: Ball out of play, Predicted Score: 0.4325
# Event: Foul, Predicted Score: 0.4323
# Event: Throw-in, Predicted Score: 0.4322
# Event: Foul, Predicted Score: 0.4320
# Event: Throw-in, Predicted Score: 0.4320
# Event: Ball out of play, Predicted Score: 0.4315
# Event: Clearance, Predicted Score: 0.4303
# Event: Shots on target, Predicted Score: 0.4292
# Event: Ball out of play, Predicted Score: 0.4291
# Event: Throw-in, Predicted Score: 0.4281
# Event: Foul, Predicted Score: 0.4280
# Event: Ball out of play, Predicted Score: 0.4277
# Event: Corner, Predicted Score: 0.4275
# Event: Direct free-kick, Predicted Score: 0.4261
# Event: Ball out of play, Predicted Score: 0.4254
# Event: Ball out of play, Predicted Score: 0.4253
# Event: Direct free-kick, Predicted Score: 0.4253
# Event: Foul, Predicted Score: 0.4252
# Event: Throw-in, Predicted Score: 0.4252
# Event: Throw-in, Predicted Score: 0.4252
# Event: Throw-in, Predicted Score: 0.4251
# Event: Indirect free-kick, Predicted Score: 0.4251
# Event: Direct free-kick, Predicted Score: 0.4251
# Event: Shots on target, Predicted Score: 0.4251
#
# Match 4:
# Event: Kick-off, Predicted Score: 0.5033
# Event: Shots on target, Predicted Score: 0.4413
# Event: Foul, Predicted Score: 0.4407
# Event: Throw-in, Predicted Score: 0.4407
# Event: Shots off target, Predicted Score: 0.4405
# Event: Ball out of play, Predicted Score: 0.4405
# Event: Throw-in, Predicted Score: 0.4405
# Event: Ball out of play, Predicted Score: 0.4403
# Event: Throw-in, Predicted Score: 0.4402
# Event: Foul, Predicted Score: 0.4400
# Event: Corner, Predicted Score: 0.4397
# Event: Throw-in, Predicted Score: 0.4397
# Event: Foul, Predicted Score: 0.4395
# Event: Ball out of play, Predicted Score: 0.4395
# Event: Ball out of play, Predicted Score: 0.4395
# Event: Shots off target, Predicted Score: 0.4385
# Event: Ball out of play, Predicted Score: 0.4382
# Event: Penalty, Predicted Score: 0.4365
# Event: Ball out of play, Predicted Score: 0.4364
# Event: Throw-in, Predicted Score: 0.4363
# Event: Clearance, Predicted Score: 0.4359
# Event: Shots on target, Predicted Score: 0.4357
# Event: Foul, Predicted Score: 0.4354
# Event: Indirect free-kick, Predicted Score: 0.4354
# Event: Clearance, Predicted Score: 0.4351
# Event: Indirect free-kick, Predicted Score: 0.4349
# Event: Direct free-kick, Predicted Score: 0.4344
# Event: Foul, Predicted Score: 0.4344
# Event: Offside, Predicted Score: 0.4343
# Event: Indirect free-kick, Predicted Score: 0.4334
# Event: Indirect free-kick, Predicted Score: 0.4330
# Event: Ball out of play, Predicted Score: 0.4327
# Event: Foul, Predicted Score: 0.4321
# Event: Throw-in, Predicted Score: 0.4321
# Event: Ball out of play, Predicted Score: 0.4318
# Event: Ball out of play, Predicted Score: 0.4316
# Event: Offside, Predicted Score: 0.4315
# Event: Foul, Predicted Score: 0.4302
# Event: Ball out of play, Predicted Score: 0.4301
# Event: Indirect free-kick, Predicted Score: 0.4298
# Event: Foul, Predicted Score: 0.4289
# Event: Indirect free-kick, Predicted Score: 0.4287
# Event: Throw-in, Predicted Score: 0.4270
# Event: Foul, Predicted Score: 0.4270
# Event: Indirect free-kick, Predicted Score: 0.4260
# Event: Indirect free-kick, Predicted Score: 0.4258
# Event: Throw-in, Predicted Score: 0.4253
# Event: Ball out of play, Predicted Score: 0.4251
# Event: Throw-in, Predicted Score: 0.4251
# Event: Throw-in, Predicted Score: 0.4250
#
# Match 5:
# Event: Kick-off, Predicted Score: 0.4927
# Event: Shots off target, Predicted Score: 0.4402
# Event: Ball out of play, Predicted Score: 0.4402
# Event: Ball out of play, Predicted Score: 0.4377
# Event: Foul, Predicted Score: 0.4367
# Event: Shots on target, Predicted Score: 0.4366
# Event: Shots on target, Predicted Score: 0.4365
# Event: Ball out of play, Predicted Score: 0.4364
# Event: Shots off target, Predicted Score: 0.4358
# Event: Shots on target, Predicted Score: 0.4356
# Event: Shots on target, Predicted Score: 0.4355
# Event: Direct free-kick, Predicted Score: 0.4354
# Event: Shots off target, Predicted Score: 0.4349
# Event: Ball out of play, Predicted Score: 0.4348
# Event: Indirect free-kick, Predicted Score: 0.4335
# Event: Ball out of play, Predicted Score: 0.4333
# Event: Ball out of play, Predicted Score: 0.4332
# Event: Corner, Predicted Score: 0.4328
# Event: Foul, Predicted Score: 0.4327
# Event: Ball out of play, Predicted Score: 0.4326
# Event: Throw-in, Predicted Score: 0.4320
# Event: Ball out of play, Predicted Score: 0.4319
# Event: Corner, Predicted Score: 0.4319
# Event: Ball out of play, Predicted Score: 0.4313
# Event: Corner, Predicted Score: 0.4310
# Event: Throw-in, Predicted Score: 0.4309
# Event: Kick-off, Predicted Score: 0.4307
# Event: Clearance, Predicted Score: 0.4303
# Event: Goal, Predicted Score: 0.4297
# Event: Throw-in, Predicted Score: 0.4297
# Event: Ball out of play, Predicted Score: 0.4297
# Event: Corner, Predicted Score: 0.4292
# Event: Indirect free-kick, Predicted Score: 0.4284
# Event: Shots on target, Predicted Score: 0.4281
# Event: Offside, Predicted Score: 0.4277
# Event: Shots off target, Predicted Score: 0.4276
# Event: Foul, Predicted Score: 0.4274
# Event: Throw-in, Predicted Score: 0.4269
# Event: Shots off target, Predicted Score: 0.4267
# Event: Ball out of play, Predicted Score: 0.4258
# Event: Ball out of play, Predicted Score: 0.4257
# Event: Ball out of play, Predicted Score: 0.4257
# Event: Ball out of play, Predicted Score: 0.4256
# Event: Clearance, Predicted Score: 0.4254
# Event: Throw-in, Predicted Score: 0.4254
# Event: Throw-in, Predicted Score: 0.4253
# Event: Throw-in, Predicted Score: 0.4253
# Event: Ball out of play, Predicted Score: 0.4253
# Event: Indirect free-kick, Predicted Score: 0.4253
# Event: Throw-in, Predicted Score: 0.4252
#
# Match 6:
# Event: Kick-off, Predicted Score: 0.5085
# Event: Shots on target, Predicted Score: 0.4413
# Event: Goal, Predicted Score: 0.4407
# Event: Ball out of play, Predicted Score: 0.4406
# Event: Ball out of play, Predicted Score: 0.4406
# Event: Ball out of play, Predicted Score: 0.4405
# Event: Kick-off, Predicted Score: 0.4405
# Event: Goal, Predicted Score: 0.4405
# Event: Ball out of play, Predicted Score: 0.4405
# Event: Clearance, Predicted Score: 0.4405
# Event: Shots off target, Predicted Score: 0.4405
# Event: Shots on target, Predicted Score: 0.4404
# Event: Foul, Predicted Score: 0.4404
# Event: Kick-off, Predicted Score: 0.4404
# Event: Indirect free-kick, Predicted Score: 0.4404
# Event: Ball out of play, Predicted Score: 0.4403
# Event: Throw-in, Predicted Score: 0.4401
# Event: Ball out of play, Predicted Score: 0.4399
# Event: Ball out of play, Predicted Score: 0.4399
# Event: Ball out of play, Predicted Score: 0.4395
# Event: Foul, Predicted Score: 0.4395
# Event: Indirect free-kick, Predicted Score: 0.4390
# Event: Foul, Predicted Score: 0.4385
# Event: Ball out of play, Predicted Score: 0.4384
# Event: Indirect free-kick, Predicted Score: 0.4381
# Event: Foul, Predicted Score: 0.4377
# Event: Foul, Predicted Score: 0.4371
# Event: Ball out of play, Predicted Score: 0.4369
# Event: Offside, Predicted Score: 0.4366
# Event: Yellow card, Predicted Score: 0.4365
# Event: Clearance, Predicted Score: 0.4364
# Event: Throw-in, Predicted Score: 0.4360
# Event: Indirect free-kick, Predicted Score: 0.4356
# Event: Ball out of play, Predicted Score: 0.4347
# Event: Indirect free-kick, Predicted Score: 0.4331
# Event: Throw-in, Predicted Score: 0.4331
# Event: Clearance, Predicted Score: 0.4327
# Event: Throw-in, Predicted Score: 0.4325
# Event: Shots on target, Predicted Score: 0.4325
# Event: Shots on target, Predicted Score: 0.4323
# Event: Throw-in, Predicted Score: 0.4322
# Event: Throw-in, Predicted Score: 0.4318
# Event: Foul, Predicted Score: 0.4315
# Event: Corner, Predicted Score: 0.4310
# Event: Foul, Predicted Score: 0.4301
# Event: Indirect free-kick, Predicted Score: 0.4281
# Event: Indirect free-kick, Predicted Score: 0.4264
# Event: Throw-in, Predicted Score: 0.4261
# Event: Corner, Predicted Score: 0.4256
# Event: Ball out of play, Predicted Score: 0.4253
#
# Match 7:
# Event: Kick-off, Predicted Score: 0.4996
# Event: Offside, Predicted Score: 0.4404
# Event: Ball out of play, Predicted Score: 0.4400
# Event: Ball out of play, Predicted Score: 0.4385
# Event: Ball out of play, Predicted Score: 0.4384
# Event: Shots on target, Predicted Score: 0.4365
# Event: Ball out of play, Predicted Score: 0.4364
# Event: Ball out of play, Predicted Score: 0.4364
# Event: Ball out of play, Predicted Score: 0.4363
# Event: Throw-in, Predicted Score: 0.4350
# Event: Ball out of play, Predicted Score: 0.4344
# Event: Throw-in, Predicted Score: 0.4343
# Event: Offside, Predicted Score: 0.4341
# Event: Offside, Predicted Score: 0.4334
# Event: Indirect free-kick, Predicted Score: 0.4331
# Event: Throw-in, Predicted Score: 0.4329
# Event: Direct free-kick, Predicted Score: 0.4327
# Event: Ball out of play, Predicted Score: 0.4318
# Event: Ball out of play, Predicted Score: 0.4312
# Event: Direct free-kick, Predicted Score: 0.4309
# Event: Yellow card, Predicted Score: 0.4303
# Event: Ball out of play, Predicted Score: 0.4301
# Event: Ball out of play, Predicted Score: 0.4297
# Event: Indirect free-kick, Predicted Score: 0.4295
# Event: Foul, Predicted Score: 0.4284
# Event: Foul, Predicted Score: 0.4276
# Event: Ball out of play, Predicted Score: 0.4276
# Event: Throw-in, Predicted Score: 0.4274
# Event: Indirect free-kick, Predicted Score: 0.4272
# Event: Direct free-kick, Predicted Score: 0.4271
# Event: Direct free-kick, Predicted Score: 0.4269
# Event: Throw-in, Predicted Score: 0.4267
# Event: Foul, Predicted Score: 0.4265
# Event: Direct free-kick, Predicted Score: 0.4262
# Event: Clearance, Predicted Score: 0.4261
# Event: Throw-in, Predicted Score: 0.4257
# Event: Throw-in, Predicted Score: 0.4256
# Event: Foul, Predicted Score: 0.4255
# Event: Direct free-kick, Predicted Score: 0.4255
# Event: Ball out of play, Predicted Score: 0.4254
# Event: Foul, Predicted Score: 0.4253
# Event: Throw-in, Predicted Score: 0.4253
# Event: Throw-in, Predicted Score: 0.4253
# Event: Corner, Predicted Score: 0.4252
# Event: Ball out of play, Predicted Score: 0.4252
# Event: Ball out of play, Predicted Score: 0.4252
# Event: Throw-in, Predicted Score: 0.4252
# Event: Throw-in, Predicted Score: 0.4251
# Event: Foul, Predicted Score: 0.4251
# Event: Clearance, Predicted Score: 0.4251
#
# Match 8:
# Event: Kick-off, Predicted Score: 0.5011
# Event: Ball out of play, Predicted Score: 0.4400
# Event: Indirect free-kick, Predicted Score: 0.4364
# Event: Clearance, Predicted Score: 0.4346
# Event: Shots on target, Predicted Score: 0.4345
# Event: Ball out of play, Predicted Score: 0.4344
# Event: Ball out of play, Predicted Score: 0.4340
# Event: Shots on target, Predicted Score: 0.4330
# Event: Ball out of play, Predicted Score: 0.4329
# Event: Ball out of play, Predicted Score: 0.4327
# Event: Throw-in, Predicted Score: 0.4323
# Event: Ball out of play, Predicted Score: 0.4322
# Event: Clearance, Predicted Score: 0.4321
# Event: Throw-in, Predicted Score: 0.4318
# Event: Direct free-kick, Predicted Score: 0.4310
# Event: Clearance, Predicted Score: 0.4309
# Event: Shots on target, Predicted Score: 0.4307
# Event: Throw-in, Predicted Score: 0.4307
# Event: Corner, Predicted Score: 0.4299
# Event: Corner, Predicted Score: 0.4295
# Event: Throw-in, Predicted Score: 0.4293
# Event: Ball out of play, Predicted Score: 0.4288
# Event: Foul, Predicted Score: 0.4286
# Event: Shots on target, Predicted Score: 0.4286
# Event: Ball out of play, Predicted Score: 0.4285
# Event: Clearance, Predicted Score: 0.4281
# Event: Ball out of play, Predicted Score: 0.4279
# Event: Foul, Predicted Score: 0.4276
# Event: Ball out of play, Predicted Score: 0.4276
# Event: Ball out of play, Predicted Score: 0.4273
# Event: Shots off target, Predicted Score: 0.4267
# Event: Ball out of play, Predicted Score: 0.4264
# Event: Indirect free-kick, Predicted Score: 0.4263
# Event: Throw-in, Predicted Score: 0.4263
# Event: Indirect free-kick, Predicted Score: 0.4262
# Event: Shots off target, Predicted Score: 0.4262
# Event: Throw-in, Predicted Score: 0.4258
# Event: Ball out of play, Predicted Score: 0.4255
# Event: Ball out of play, Predicted Score: 0.4254
# Event: Foul, Predicted Score: 0.4253
# Event: Throw-in, Predicted Score: 0.4253
# Event: Ball out of play, Predicted Score: 0.4252
# Event: Clearance, Predicted Score: 0.4252
# Event: Clearance, Predicted Score: 0.4252
# Event: Throw-in, Predicted Score: 0.4251
# Event: Foul, Predicted Score: 0.4251
# Event: Ball out of play, Predicted Score: 0.4251
# Event: Ball out of play, Predicted Score: 0.4251
# Event: Ball out of play, Predicted Score: 0.4249
# Event: Corner, Predicted Score: 0.4208
#
# Match 9:
# Event: Kick-off, Predicted Score: 0.5099
# Event: Throw-in, Predicted Score: 0.4404
# Event: Offside, Predicted Score: 0.4400
# Event: Throw-in, Predicted Score: 0.4398
# Event: Foul, Predicted Score: 0.4394
# Event: Shots on target, Predicted Score: 0.4385
# Event: Ball out of play, Predicted Score: 0.4383
# Event: Ball out of play, Predicted Score: 0.4375
# Event: Ball out of play, Predicted Score: 0.4371
# Event: Ball out of play, Predicted Score: 0.4369
# Event: Shots off target, Predicted Score: 0.4366
# Event: Yellow card, Predicted Score: 0.4365
# Event: Ball out of play, Predicted Score: 0.4363
# Event: Throw-in, Predicted Score: 0.4361
# Event: Indirect free-kick, Predicted Score: 0.4360
# Event: Throw-in, Predicted Score: 0.4360
# Event: Throw-in, Predicted Score: 0.4357
# Event: Ball out of play, Predicted Score: 0.4356
# Event: Ball out of play, Predicted Score: 0.4355
# Event: Throw-in, Predicted Score: 0.4351
# Event: Shots off target, Predicted Score: 0.4351
# Event: Ball out of play, Predicted Score: 0.4347
# Event: Ball out of play, Predicted Score: 0.4345
# Event: Throw-in, Predicted Score: 0.4345
# Event: Corner, Predicted Score: 0.4335
# Event: Ball out of play, Predicted Score: 0.4333
# Event: Throw-in, Predicted Score: 0.4330
# Event: Throw-in, Predicted Score: 0.4328
# Event: Foul, Predicted Score: 0.4327
# Event: Throw-in, Predicted Score: 0.4327
# Event: Throw-in, Predicted Score: 0.4326
# Event: Corner, Predicted Score: 0.4326
# Event: Ball out of play, Predicted Score: 0.4325
# Event: Ball out of play, Predicted Score: 0.4324
# Event: Throw-in, Predicted Score: 0.4323
# Event: Ball out of play, Predicted Score: 0.4321
# Event: Ball out of play, Predicted Score: 0.4319
# Event: Throw-in, Predicted Score: 0.4315
# Event: Foul, Predicted Score: 0.4314
# Event: Indirect free-kick, Predicted Score: 0.4310
# Event: Throw-in, Predicted Score: 0.4307
# Event: Throw-in, Predicted Score: 0.4303
# Event: Indirect free-kick, Predicted Score: 0.4296
# Event: Ball out of play, Predicted Score: 0.4278
# Event: Ball out of play, Predicted Score: 0.4274
# Event: Ball out of play, Predicted Score: 0.4264
# Event: Ball out of play, Predicted Score: 0.4254
# Event: Indirect free-kick, Predicted Score: 0.4254
# Event: Ball out of play, Predicted Score: 0.4253
# Event: Clearance, Predicted Score: 0.4252
#
# Match 10:
# Event: Kick-off, Predicted Score: 0.5083
# Event: Shots on target, Predicted Score: 0.4417
# Event: Offside, Predicted Score: 0.4408
# Event: Throw-in, Predicted Score: 0.4406
# Event: Ball out of play, Predicted Score: 0.4406
# Event: Throw-in, Predicted Score: 0.4405
# Event: Shots on target, Predicted Score: 0.4405
# Event: Ball out of play, Predicted Score: 0.4405
# Event: Foul, Predicted Score: 0.4405
# Event: Ball out of play, Predicted Score: 0.4404
# Event: Ball out of play, Predicted Score: 0.4404
# Event: Throw-in, Predicted Score: 0.4404
# Event: Throw-in, Predicted Score: 0.4403
# Event: Throw-in, Predicted Score: 0.4403
# Event: Ball out of play, Predicted Score: 0.4403
# Event: Ball out of play, Predicted Score: 0.4403
# Event: Ball out of play, Predicted Score: 0.4403
# Event: Indirect free-kick, Predicted Score: 0.4402
# Event: Ball out of play, Predicted Score: 0.4402
# Event: Offside, Predicted Score: 0.4402
# Event: Foul, Predicted Score: 0.4400
# Event: Ball out of play, Predicted Score: 0.4400
# Event: Indirect free-kick, Predicted Score: 0.4400
# Event: Foul, Predicted Score: 0.4396
# Event: Ball out of play, Predicted Score: 0.4395
# Event: Ball out of play, Predicted Score: 0.4392
# Event: Offside, Predicted Score: 0.4386
# Event: Throw-in, Predicted Score: 0.4385
# Event: Ball out of play, Predicted Score: 0.4379
# Event: Indirect free-kick, Predicted Score: 0.4377
# Event: Indirect free-kick, Predicted Score: 0.4372
# Event: Clearance, Predicted Score: 0.4368
# Event: Indirect free-kick, Predicted Score: 0.4365
# Event: Shots off target, Predicted Score: 0.4365
# Event: Throw-in, Predicted Score: 0.4365
# Event: Substitution, Predicted Score: 0.4364
# Event: Ball out of play, Predicted Score: 0.4364
# Event: Corner, Predicted Score: 0.4362
# Event: Ball out of play, Predicted Score: 0.4360
# Event: Clearance, Predicted Score: 0.4359
# Event: Foul, Predicted Score: 0.4350
# Event: Ball out of play, Predicted Score: 0.4345
# Event: Clearance, Predicted Score: 0.4345
# Event: Throw-in, Predicted Score: 0.4341
# Event: Ball out of play, Predicted Score: 0.4338
# Event: Throw-in, Predicted Score: 0.4334
# Event: Throw-in, Predicted Score: 0.4328
# Event: Indirect free-kick, Predicted Score: 0.4327
# Event: Indirect free-kick, Predicted Score: 0.4325
# Event: Throw-in, Predicted Score: 0.4287
#
# Test Results: Loss: 0.6850, MAE: 0.1525, Accuracy: 0.0080
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_mae</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_accuracy</td><td>0.008</td></tr><tr><td>test_loss</td><td>0.68497</td></tr><tr><td>test_mae</td><td>0.15252</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">decent-sun-12</strong> at: <a href='https://wandb.ai/fyproject/soccernet_highlights-test/runs/uvvhr68l' target="_blank">https://wandb.ai/fyproject/soccernet_highlights-test/runs/uvvhr68l</a><br> View project at: <a href='https://wandb.ai/fyproject/soccernet_highlights-test' target="_blank">https://wandb.ai/fyproject/soccernet_highlights-test</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250506_060615-uvvhr68l/logs</code>
